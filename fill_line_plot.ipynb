# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('data_for_fill_line_plot.csv')

# %%
df.tail(5)
# Out:
#     Age  All_Devs  Python  JavaScript
# 33   51     98988  108423       91660
# 34   52    100000  101407       99240
# 35   53    108923  112542      108000
# 36   54    105000  122870      105000
# 37   55    103117  120000      104000

# %%
ages = df['Age']
all_dev_sal = df['All_Devs']
py_dev_sal = df['Python']
js_dev_sal = df['JavaScript']

# %%
plt.style.use('ggplot')
overall_median = 57287

plt.plot(ages, all_dev_sal, label='all_dev')
plt.plot(ages, py_dev_sal, label='python')

plt.fill_between(ages, py_dev_sal, overall_median, alpha=0.25)

plt.title('Salaries Per Programming Languages On Age Ranges', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.legend()
plt.tight_layout()

plt.show()

# %%
plt.style.use('ggplot')
overall_median = 57287

plt.plot(ages, all_dev_sal, label='all_dev')
plt.plot(ages, py_dev_sal, label='python')

plt.fill_between(ages,
                 py_dev_sal,
                 overall_median,
                 where=(py_dev_sal > overall_median),
                 color='g',
                 interpolate=True,
                 alpha=0.25,
                 label='Above Avg'
                )

plt.fill_between(ages,
                 py_dev_sal,
                 overall_median,
                 where=(py_dev_sal <= overall_median),
                 color='r',
                 interpolate=True,
                 alpha=0.25,
                 label='Below Avg'
                )


plt.title('Salaries Per Programming Languages On Age Ranges', fontsize=15)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Salary', fontsize=12)
plt.legend()
plt.tight_layout()

plt.show()
